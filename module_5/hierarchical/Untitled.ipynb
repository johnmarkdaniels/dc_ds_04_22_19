# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
shop = pd.read_excel('Online Retail.xlsx')

# %%
shop.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
shop.dropna(inplace=True)

# %%
df = pd.DataFrame(shop['CustomerID'])

# %%
df['CustomerID'].astype('int')
# Out:
# 0         17850
# 1         17850
# 2         17850
# 3         17850
# 4         17850
# 5         17850
# 6         17850
# 7         17850
# 8         17850
# 9         13047
# 10        13047
# 11        13047
# 12        13047
# 13        13047
# 14        13047
# 15        13047
# 16        13047
# 17        13047
# 18        13047
# 19        13047
# 20        13047
# 21        13047
# 22        13047
# 23        13047
# 24        13047
# 25        13047
# 26        12583
# 27        12583
# 28        12583
# 29        12583
#           ...
# 541879    15804
# 541880    15804
# 541881    15804
# 541882    15804
# 541883    15804
# 541884    15804
# 541885    15804
# 541886    15804
# 541887    15804
# 541888    15804
# 541889    15804
# 541890    13113
# 541891    13113
# 541892    13113
# 541893    13113
# 541894    12680
# 541895    12680
# 541896    12680
# 541897    12680
# 541898    12680
# 541899    12680
# 541900    12680
# 541901    12680
# 541902    12680
# ...

# %%
df = pd.DataFrame(shop['CustomerID'].unique())

# %%
df.head()
# Out:
#          0
# 0  17850.0
# 1  13047.0
# 2  12583.0
# 3  13748.0
# 4  15100.0

# %%
df = df.astype('int')

# %%
df.head()
# Out:
#        0
# 0  17850
# 1  13047
# 2  12583
# 3  13748
# 4  15100

# %%
shop.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom    15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom    22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34

# %%
shop['Revenue'] = shop['Quantity']*shop['UnitPrice']

# %%
shop.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom    15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom    22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34

# %%
revbycust['CustomerID'] = pd.DataFrame(shop['CustomerID'])

# %%
revbycust.head()
# Out:
#             Revenue  CustomerID
# CustomerID
# 17850         15.30     17341.0
# 17850         20.34     17341.0
# 17850         22.00     17341.0
# 17850         20.34     17341.0
# 17850         20.34     17341.0

# %%
revbycust.groupby(['CustomerID']).sum()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: 'CustomerID' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   """Entry point for launching an IPython kernel.
#                Revenue
# CustomerID
# 12347.0      28206.370
# 12386.0      11330.270
# 12441.0       7444.250
# 12567.0      15417.320
# 12647.0      16308.920
# 12681.0     150371.760
# 12709.0       6173.950
# 12712.0        103.300
# 12748.0     213612.970
# 12766.0       4189.580
# 12839.0      43181.150
# 12913.0      16605.670
# 12921.0      12274.620
# 12971.0       2128.740
# 13030.0      57210.200
# 13050.0       6289.920
# 13078.0       9145.910
# 13089.0      65407.170
# 13113.0       5074.310
# 13126.0      18140.180
# 13173.0      14074.530
# 13199.0       8448.090
# 13267.0      14508.750
# 13319.0       3757.220
# 13329.0      11915.890
# 13455.0      27619.990
# 13468.0      21921.550
# ...

# %%
df['Revenue'] = revbycust['Revenue']

# %%
df.head()
# Out:
#        0  Revenue
# 0  17850      NaN
# 1  13047      NaN
# 2  12583      NaN
# 3  13748      NaN
# 4  15100      NaN
